# %%
# %run -i "test_0020_noise_detection.py"
# Out:
# ['img-noise']
# ['img-noise']
# [INF] noise-map
# [INF] noise-map: : map noisy pixels, frames in folder: ./img-noise
# noise-map:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] noise-map: hot pixels, r: 35
# [INF] noise-map: hot pixels, g: 5
# [INF] noise-map: hot pixels, b: 7
# [INF] noise-map: hot pixels, rgb: 36
# [INF] noise-map: elapsed time: 00:00:00.70s
# [INF] noise-map: completed
# [INF] job: elapsed time: 00:00:00.70s
# [INF] job: completed
