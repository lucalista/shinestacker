# %%
from focus_stack.utils import copy_exif

# %%
exif_filename = 'E:/Focus stacking/2024-05-04 - Leaf/A/src/_MG_1894.tif'
in_filename = 'E:/Focus stacking/2024-05-04 - Leaf/A/stack/_MG_1894_pyr.tif'
#exif_filename = 'E:/Focus stacking/2024-04-21 - Fulgomorpha/src/_MG_8734.jpg'
#in_filename = 'E:/Focus stacking/2024-04-21 - Fulgomorpha/stack/_MG_8734_stack_pyr.jpg'
out_filename = 'C:/Users/Luca Lista/Desktop/Temp/test_exif.tiff'

# %%
copy_exif(exif_filename, in_filename, out_filename, verbose=True)
# Out:
# ImageWidth                [#256]: 5616
# ImageLength               [#257]: 3744
# BitsPerSample             [#258]: (16, 16, 16)
# Compression               [#259]: 1
# PhotometricInterpretation [#262]: 2
# ImageResources            [#34377]: <<< decode error >>>
# Make                      [#271]: Canon
# Model                     [#272]: Canon EOS 5D Mark II
# StripOffsets              [#273]: (25630,)
# SamplesPerPixel           [#277]: 3
# RowsPerStrip              [#278]: 3744
# StripByteCounts           [#279]: (126157824,)
# XResolution               [#282]: 240.0
# YResolution               [#283]: 240.0
# PlanarConfiguration       [#284]: 1
# ResolutionUnit            [#296]: 2
# <<< skipped >>>           [#34665]: <<< bad key for TIFF format in PIL module >>>
# Software                  [#305]: Adobe Photoshop Lightroom Classic 13.1 (Windows)
# DateTime                  [#306]: 2024:05:05 15:23:39
# InterColorProfile         [#34675]: <<< decode error >>>
# ...
